# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
n0901 = pd.read_csv("2009-01.csv", encoding="utf-8", index_col=0)
n0902 = pd.read_csv("2009-02.csv", encoding="utf-8", index_col=0)
n0903 = pd.read_csv("2009-03.csv", encoding="utf-8", index_col=0)
n0904 = pd.read_csv("2009-04.csv", encoding="utf-8", index_col=0)
n0905 = pd.read_csv("2009-05.csv", encoding="utf-8", index_col=0)
n0906 = pd.read_csv("2009-06.csv", encoding="utf-8", index_col=0)
n0907 = pd.read_csv("2009-07.csv", encoding="utf-8", index_col=0)
n0908 = pd.read_csv("2009-08.csv", encoding="utf-8", index_col=0)
n0909 = pd.read_csv("2009-09.csv", encoding="utf-8", index_col=0)
n0910 = pd.read_csv("2009-10.csv", encoding="utf-8", index_col=0)
n0911 = pd.read_csv("2009-11.csv", encoding="utf-8", index_col=0)
n0912 = pd.read_csv("2009-12.csv", encoding="utf-8", index_col=0)
n1001 = pd.read_csv("2010-01.csv", encoding="utf-8", index_col=0)
n1002 = pd.read_csv("2010-02.csv", encoding="utf-8", index_col=0)
n1003 = pd.read_csv("2010-03.csv", encoding="utf-8", index_col=0)
n1004 = pd.read_csv("2010-04.csv", encoding="utf-8", index_col=0)
n1005 = pd.read_csv("2010-05.csv", encoding="utf-8", index_col=0)
n1006 = pd.read_csv("2010-06.csv", encoding="utf-8", index_col=0)
n1007 = pd.read_csv("2010-07.csv", encoding="utf-8", index_col=0)
n1008 = pd.read_csv("2010-08.csv", encoding="utf-8", index_col=0)
n1009 = pd.read_csv("2010-09.csv", encoding="utf-8", index_col=0)
n1010 = pd.read_csv("2010-10.csv", encoding="utf-8", index_col=0)
n1011 = pd.read_csv("2010-11.csv", encoding="utf-8", index_col=0)
n1012 = pd.read_csv("2010-12.csv", encoding="utf-8", index_col=0)
n1101 = pd.read_csv("2011-01.csv", encoding="utf-8", index_col=0)
n1102 = pd.read_csv("2011-02.csv", encoding="utf-8", index_col=0)
n1103 = pd.read_csv("2011-03.csv", encoding="utf-8", index_col=0)
n1104 = pd.read_csv("2011-04.csv", encoding="utf-8", index_col=0)
n1105 = pd.read_csv("2011-05.csv", encoding="utf-8", index_col=0)
n1106 = pd.read_csv("2011-06.csv", encoding="utf-8", index_col=0)
n1107 = pd.read_csv("2011-07.csv", encoding="utf-8", index_col=0)
n1108 = pd.read_csv("2011-08.csv", encoding="utf-8", index_col=0)
n1109 = pd.read_csv("2011-09.csv", encoding="utf-8", index_col=0)
n1110 = pd.read_csv("2011-10.csv", encoding="utf-8", index_col=0)
n1111 = pd.read_csv("2011-11.csv", encoding="utf-8", index_col=0)
n1112 = pd.read_csv("2011-12.csv", encoding="utf-8", index_col=0)
n1201 = pd.read_csv("2012-01.csv", encoding="utf-8", index_col=0)
n1202 = pd.read_csv("2012-02.csv", encoding="utf-8", index_col=0)
n1203 = pd.read_csv("2012-03.csv", encoding="utf-8", index_col=0)
n1204 = pd.read_csv("2012-04.csv", encoding="utf-8", index_col=0)
n1205 = pd.read_csv("2012-05.csv", encoding="utf-8", index_col=0)
n1206 = pd.read_csv("2012-06.csv", encoding="utf-8", index_col=0)
n1207 = pd.read_csv("2012-07.csv", encoding="utf-8", index_col=0)
n1208 = pd.read_csv("2012-08.csv", encoding="utf-8", index_col=0)
n1209 = pd.read_csv("2012-09.csv", encoding="utf-8", index_col=0)
n1210 = pd.read_csv("2012-10.csv", encoding="utf-8", index_col=0)
n1211 = pd.read_csv("2012-11.csv", encoding="utf-8", index_col=0)
n1212 = pd.read_csv("2012-12.csv", encoding="utf-8", index_col=0)
n1301 = pd.read_csv("2013-01.csv", encoding="utf-8", index_col=0)
n1302 = pd.read_csv("2013-02.csv", encoding="utf-8", index_col=0)
n1303 = pd.read_csv("2013-03.csv", encoding="utf-8", index_col=0)
n1304 = pd.read_csv("2013-04.csv", encoding="utf-8", index_col=0)
n1305 = pd.read_csv("2013-05.csv", encoding="utf-8", index_col=0)
n1306 = pd.read_csv("2013-06.csv", encoding="utf-8", index_col=0)
n1307 = pd.read_csv("2013-07.csv", encoding="utf-8", index_col=0)
n1308 = pd.read_csv("2013-08.csv", encoding="utf-8", index_col=0)
n1309 = pd.read_csv("2013-09.csv", encoding="utf-8", index_col=0)
n1310 = pd.read_csv("2013-10.csv", encoding="utf-8", index_col=0)
n1311 = pd.read_csv("2013-11.csv", encoding="utf-8", index_col=0)
n1312 = pd.read_csv("2013-12.csv", encoding="utf-8", index_col=0)
n1401 = pd.read_csv("2014-01.csv", encoding="utf-8", index_col=0)
n1402 = pd.read_csv("2014-02.csv", encoding="utf-8", index_col=0)
n1403 = pd.read_csv("2014-03.csv", encoding="utf-8", index_col=0)
n1404 = pd.read_csv("2014-04.csv", encoding="utf-8", index_col=0)
n1405 = pd.read_csv("2014-05.csv", encoding="utf-8", index_col=0)
n1406 = pd.read_csv("2014-06.csv", encoding="utf-8", index_col=0)
n1407 = pd.read_csv("2014-07.csv", encoding="utf-8", index_col=0)
n1408 = pd.read_csv("2014-08.csv", encoding="utf-8", index_col=0)
n1409 = pd.read_csv("2014-09.csv", encoding="utf-8", index_col=0)
n1410 = pd.read_csv("2014-10.csv", encoding="utf-8", index_col=0)
n1411 = pd.read_csv("2014-11.csv", encoding="utf-8", index_col=0)
n1412 = pd.read_csv("2014-12.csv", encoding="utf-8", index_col=0)
n1501 = pd.read_csv("2015-01.csv", encoding="utf-8", index_col=0)
n1502 = pd.read_csv("2015-02.csv", encoding="utf-8", index_col=0)
n1503 = pd.read_csv("2015-03.csv", encoding="utf-8", index_col=0)
n1504 = pd.read_csv("2015-04.csv", encoding="utf-8", index_col=0)
n1505 = pd.read_csv("2015-05.csv", encoding="utf-8", index_col=0)
n1506 = pd.read_csv("2015-06.csv", encoding="utf-8", index_col=0)
n1507 = pd.read_csv("2015-07.csv", encoding="utf-8", index_col=0)
n1508 = pd.read_csv("2015-08.csv", encoding="utf-8", index_col=0)
n1509 = pd.read_csv("2015-09.csv", encoding="utf-8", index_col=0)
n1510 = pd.read_csv("2015-10.csv", encoding="utf-8", index_col=0)
n1511 = pd.read_csv("2015-11.csv", encoding="utf-8", index_col=0)
n1512 = pd.read_csv("2015-12.csv", encoding="utf-8", index_col=0)
n1601 = pd.read_csv("2016-01.csv", encoding="utf-8", index_col=0)
n1602 = pd.read_csv("2016-02.csv", encoding="utf-8", index_col=0)
n1603 = pd.read_csv("2016-03.csv", encoding="utf-8", index_col=0)
n1604 = pd.read_csv("2016-04.csv", encoding="utf-8", index_col=0)
n1605 = pd.read_csv("2016-05.csv", encoding="utf-8", index_col=0)
n1606 = pd.read_csv("2016-06.csv", encoding="utf-8", index_col=0)
n1607 = pd.read_csv("2016-07.csv", encoding="utf-8", index_col=0)
n1608 = pd.read_csv("2016-08.csv", encoding="utf-8", index_col=0)
n1609 = pd.read_csv("2016-09.csv", encoding="utf-8", index_col=0)
n1610 = pd.read_csv("2016-10.csv", encoding="utf-8", index_col=0)
n1611 = pd.read_csv("2016-11.csv", encoding="utf-8", index_col=0)
n1612 = pd.read_csv("2016-12.csv", encoding="utf-8", index_col=0)
n1701 = pd.read_csv("2017-01.csv", encoding="utf-8", index_col=0)
n1702 = pd.read_csv("2017-02.csv", encoding="utf-8", index_col=0)
n1703 = pd.read_csv("2017-03.csv", encoding="utf-8", index_col=0)
n1704 = pd.read_csv("2017-04.csv", encoding="utf-8", index_col=0)
n1705 = pd.read_csv("2017-05.csv", encoding="utf-8", index_col=0)
n1706 = pd.read_csv("2017-06.csv", encoding="utf-8", index_col=0)
n1707 = pd.read_csv("2017-07.csv", encoding="utf-8", index_col=0)
n1708 = pd.read_csv("2017-08.csv", encoding="utf-8", index_col=0)
n1709 = pd.read_csv("2017-09.csv", encoding="utf-8", index_col=0)
n1710 = pd.read_csv("2017-10.csv", encoding="utf-8", index_col=0)
n1711 = pd.read_csv("2017-11.csv", encoding="utf-8", index_col=0)
n1712 = pd.read_csv("2017-12.csv", encoding="utf-8", index_col=0)
n1801 = pd.read_csv("2018-01.csv", encoding="utf-8", index_col=0)
n1802 = pd.read_csv("2018-02.csv", encoding="utf-8", index_col=0)
n1803 = pd.read_csv("2018-03.csv", encoding="utf-8", index_col=0)
n1804 = pd.read_csv("2018-04.csv", encoding="utf-8", index_col=0)
n1805 = pd.read_csv("2018-05.csv", encoding="utf-8", index_col=0)
n1806 = pd.read_csv("2018-06.csv", encoding="utf-8", index_col=0)
n1807 = pd.read_csv("2018-07.csv", encoding="utf-8", index_col=0)
n1808 = pd.read_csv("2018-08.csv", encoding="utf-8", index_col=0)
n1809 = pd.read_csv("2018-09.csv", encoding="utf-8", index_col=0)
n1810 = pd.read_csv("2018-10.csv", encoding="utf-8", index_col=0)
n1811 = pd.read_csv("2018-11.csv", encoding="utf-8", index_col=0)
n1812 = pd.read_csv("2018-12.csv", encoding="utf-8", index_col=0)
n1901 = pd.read_csv("2019-01.csv", encoding="utf-8", index_col=0)
n1902 = pd.read_csv("2019-02.csv", encoding="utf-8", index_col=0)
n1903 = pd.read_csv("2019-03.csv", encoding="utf-8", index_col=0)
n1904 = pd.read_csv("2019-04.csv", encoding="utf-8", index_col=0)
n1905 = pd.read_csv("2019-05.csv", encoding="utf-8", index_col=0)

# %%
n0901
# Out:
#            id
# 0       26.68
# 1      107.73
# 2       94.88
# 3       95.87
# 4       97.85
# ...       ...
# 78582  123.55
# 78583   15.81
# 78584   36.57
# 78585   95.87
# 78586   95.87
#
# [78587 rows x 1 columns]

# %%
merge_data=pd.concat([n0901,n0902,n0903,n0904,n0905,n0906,n0907,n0908,n0909,n0910,n0911,n0912,
                      n1001,n1002,n1003,n1004,n1005,n1006,n1007,n1008,n1009,n1010,n1011,n1012,
                      n1101,n1102,n1103,n1104,n1105,n1106,n1107,n1108,n1109,n1110,n1111,n1112,
                      n1201,n1202,n1203,n1204,n1205,n1206,n1207,n1208,n1209,n1210,n1211,n1212,
                      n1301,n1302,n1303,n1304,n1305,n1306,n1307,n1308,n1309,n1310,n1311,n1312,
                      n1401,n1402,n1403,n1404,n1405,n1406,n1407,n1408,n1409,n1410,n1411,n1412,
                      n1501,n1502,n1503,n1504,n1505,n1506,n1507,n1508,n1509,n1510,n1511,n1512,
                      n1601,n1602,n1603,n1604,n1605,n1606,n1607,n1608,n1609,n1610,n1611,n1612,
                      n1701,n1702,n1703,n1704,n1705,n1706,n1707,n1708,n1709,n1710,n1711,n1712,
                      n1801,n1802,n1803,n1804,n1805,n1806,n1807,n1808,n1809,n1810,n1811,n1812,
                      n1901,n1902,n1903,n1904,n1905],axis=1)
merge_data.to_csv('resampling.csv')
